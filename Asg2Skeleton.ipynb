# %% [markdown]
# Deep Learning Programming Assignment 2
# --------------------------------------
# Name:
# Roll No.:
#
# Submission Instructions:
# 1. Fill your name and roll no in the space provided above.
# 2. Name your folder in format <Roll No>_<First Name>.
#     For example 12CS10001_Rohan
# 3. Submit a zipped format of the file (.zip only).
# 4. Submit all your codes. But do not submit any of your datafiles
# 5. From output files submit only the following 3 files. simOutput.csv, simSummary.csv, analogySolution.csv
# 6. Place the three files in a folder "output", inside the zip.

# %%
import gzip
import os

## paths to files. Do not change this
simInputFile = "Q1/word-similarity-dataset"
analogyInputFile = "Q1/word-analogy-dataset"
vectorgzipFile = "Q1/glove.6B.300d.txt.gz"
vectorTxtFile = "Q1/glove.6B.300d.txt"   # If you extract and use the gz file, use this.
analogyTrainPath = "Q1/wordRep/"
simOutputFile = "Q1/simOutput.csv"
simSummaryFile = "Q1/simSummary.csv"
anaSOln = "Q1/analogySolution.csv"
Q4List = "Q4/wordList.csv"

# %%
# Similarity Dataset
simDataset = [item.split(" | ") for item in open(simInputFile).read().splitlines()]
# Analogy dataset
analogyDataset = [[stuff.strip() for stuff in item.strip('\n').split('\n')] for item in open(analogyInputFile).read().split('\n\n')]

def vectorExtract(simD = simDataset, anaD = analogyDataset, vect = vectorgzipFile):
    simList = [stuff for item in simD for stuff in item]
    analogyList = [thing for item in anaD for stuff in item[0:4] for thing in stuff.split()]
    simList.extend(analogyList)
    wordList = set(simList)
    print(len(wordList))
    wordDict = dict()
    
    vectorFile = gzip.open(vect, 'r')
    for line in vectorFile:
        if line.split()[0].strip() in wordList:
            wordDict[line.split()[0].strip()] = line.split()[1:]
    
    
    vectorFile.close()
    print('retrieved', len(wordDict.keys()))
    return wordDict

# Extracting Vectors from Analogy and Similarity Dataset
validateVectors = vectorExtract()
# Out:
# 895
# retrieved 0

# %%
# Dictionary of training pairs for the analogy task
trainDict = dict()
for subDirs in os.listdir(analogyTrainPath):
    for files in os.listdir(analogyTrainPath+subDirs+'/'):
        f = open(analogyTrainPath+subDirs+'/'+files).read().splitlines()
        trainDict[files] = f
print(len(trainDict.keys()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-8273abd051fe> in <module>()
#       1 # Dictionary of training pairs for the analogy task
#       2 trainDict = dict()
# ----> 3 for subDirs in os.listdir(analogyTrainPath):
#       4     for files in os.listdir(analogyTrainPath+subDirs+'/'):
#       5         f = open(analogyTrainPath+subDirs+'/'+files).read().splitlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Q1/wordRep/'

# %%
def similarityTask(inputDS = simDataset, outputFile = simOutputFile, summaryFile=simSummaryFile, vectors=validateVectors):
    print('hello world')

    """
    Output simSummary.csv in the following format
    Distance Metric, Number of questions which are correct, Total questions evalauted, MRR
    C, 37, 40, 0.61
    """

    """
    Output a CSV file titled "simOutput.csv" with the following columns

    file_line-number, query word, option word i, distance metric(C/E/M), similarity score 

    For the line "rusty | corroded | black | dirty | painted", the outptut will be

    1,rusty,corroded,C,0.7654
    1,rusty,dirty,C,0.8764
    1,rusty,black,C,0.6543


    The order in which rows are entered does not matter and so do Row header names. Please follow the order of columns though.
    """

# %%
def analogyTask(inputDS=analogyDataset,outputFile = anaSoln ): # add more arguments if required
    
    """
    Output a file, analogySolution.csv with the following entris
    Query word pair, Correct option, predicted option    
    """
    
    
    return accuracy #return the accuracy of your model after 5 fold cross validation

# %%
def derivedWOrdTask(inputFile = Q4List):
    print('hello world')
    
    """
    Output vectors of 3 files:
    1)AnsFastText.txt - fastText vectors of derived words in wordList.csv
    2)AnsLzaridou.txt - Lazaridou vectors of the derived words in wordList.csv
    3)AnsModel.txt - Vectors for derived words as provided by the model
    
    For all the three files, each line should contain a derived word and its vector, exactly like 
    the format followed in "glove.6B.300d.txt"
    
    word<space>dim1<space>dim2........<space>dimN
    charitably 256.238 0.875 ...... 1.234
    
    """
    
    """
    The function should return 2 values
    1) Averaged cosine similarity between the corresponding words from output files 1 and 3, as well as 2 and 3.
    
        - if there are 3 derived words in wordList.csv, say word1, word2, word3
        then find the cosine similiryt between word1 in AnsFastText.txt and word1 in AnsModel.txt.
        - Repeat the same for word2 and word3.
        - Average the 3 cosine similarity values
        - DO the same for word1 to word3 between the files AnsLzaridou.txt and AnsModel.txt 
        and average the cosine simialities for valuse so obtained
        
    """
    return cosVal1,cosVal2

# %%
def main():
    similarityTask()
    anaSim = analogyTask()
    derCos1,derCos2 = derivedWordTask
    
if __name__ == '__main__':
    main()

# %%
'''
simD = simDataset
anaD = analogyDataset
simList = [stuff for item in simD for stuff in item]
analogyList = [thing for item in anaD for stuff in item[0:4] for thing in stuff.split()]
simList.extend(analogyList)
wordList = set(simList)
print(len(wordList))
wordDict = dict()
'''
i = 0
vectorFile = gzip.open(vectorgzipFile, 'r')
for line in vectorFile:
        #l = line.split()[0]
        #l=str(l,"utf-8")
        #print(l, str(l))
        
        if str(line.split()[0].strip(),"utf-8") in wordList:
            #s = str(line.split()[0].strip(),"utf-8")
            s = line.split()[0].strip().decode("utf-8")
            print(s)
            wordDict[s] = line.split()[1:]
print(wordDict.keys())
# Out:
# one
# people
# time
# president
# city
# day
# group
# officials
# work
# school
# game
# take
# security
# bank
# members
# see
# think
# service
# chief
# play
# office
# meeting
# want
# case
# run
# money
# name
# film
# air
# army
# line
# head
# night
# election
# statement
# plan
# music
# need
# water
# due
# building
# round
# nations
# players
# move
# fire
# eight
# black
# story
# policy
# board
# book
# agreement
# growth
# food
# period
# term
# opposition
# call
# century
# index
# coach
# energy
# short
# key
# red
# victory
# title
# violence
# body
# division
# hospital
# course
# band
# trial
# song
# hand
# hope
# stop
# fight
# manager
# light
# evidence
# society
# stage
# construction
# movement
# room
# computer
# demand
# events
# cooperation
# prison
# attention
# firm
# movie
# language
# rest
# stalk
# barricade
# shove
# plow
# soluble
# shabby
# relapse
# starve
# radiant
# insomnia
# veer
# eulogy
# refinement
# blueprints
# ostrich
# abrasive
# grudgingly
# balk
# orator
# hoist
# gaunt
# bruise
# elude
# parched
# chronicler
# larceny
# fathom
# whittle
# elevating
# crib
# amiable
# cleanse
# contour
# treachery
# frugal
# subtitle
# outcast
# carnivorous
# epilogue
# crass
# debatable
# brag
# jubilation
# stomp
# ache
# fortitude
# genial
# grate
# coop
# quart
# remuneration
# apologetic
# slumber
# softness
# sew
# amplify
# forlorn
# thicket
# sully
# rehearse
# blackboard
# banish
# tranquillity
# devour
# envious
# tanned
# adulation
# habitable
# disprove
# lotion
# condescending
# dingy
# recklessness
# corroborate
# straddle
# viscous
# octagon
# binomial
# heckler
# tiff
# livid
# flipper
# lubricant
# modulated
# obliging
# gooey
# foolhardy
# carnal
# decibel
# twig
# dangle
# raspy
# cartographer
# ewe
# cask
# enlighten
# impure
# mutter
# bicker
# corroded
# exhortation
# swerve
# immunize
# magnify
# cajole
# erasure
# ramble
# condense
# separable
# ostracism
# cloying
# indiscretion
# bashful
# demagogue
# rotund
# destitution
# scoundrel
# pallid
# odometer
# scamper
# appraise
# rowboat
# loudness
# feign
# demean
# clairvoyant
# gratuity
# illegible
# twirl
# discolored
# tourniquet
# servile
# affectation
# vex
# lubricate
# refracted
# mendicant
# glutton
# bibliographer
# gourmand
# truculent
# avaricious
# perfidious
# torpid
# merrymaking
# wastefulness
# braggart
# abridge
# worthlessness
# hedonist
# querulous
# sycophant
# reveler
# submissiveness
# congeal
# entreat
# choleric
# catnap
# pinioned
# disconcert
# malinger
# dict_keys([b'period', b'lion', b'museum', b'send', 'name', 'compassion', b'honey', b'recruit', b'film', b'heal', 'dingy', 'chronicler', b'gaunt', b'tutor', 'diploma', b'bag', b'limit', 'museum', 'dot', b'ethos', 'shout', 'appraise', b'softness', b'loyalty', b'theorist', 'head', b'novel', b'president', 'wrong', b'abridge', 'solid', b'cooked', 'speak', 'fracture', b'mine', b'pointed', 'stomp', 'skin', 'employer', b'teacher', b'assurance', b'animal', 'magnify', b'glutton', 'recruit', b'braggart', b'quart', b'playwright', b'precious', b'band', b'morality', b'boundaries', b'uproar', b'day', 'sprint', 'take', b'shame', 'soldier', b'title', b'evidence', 'repaired', b'polish', b'observer', b'dark', b'raspy', 'terminate', 'rife', b'values', b'fertilizer', b'greet', b'crib', 'artworks', 'boast', b'submissiveness', b'practiced', b'stalk', 'bleeding', 'generous', 'funny', 'debatable', 'parched', b'tree', 'dim', 'paint', b'service', 'swear', 'tutor', 'disease', b'ear', b'sequel', 'enmity', b'microscope', 'fathom', 'bag', 'limit', b'judgment', b'franchise', b'submit', b'air', 'jubilation', 'obedience', b'condense', 'elongated', b'illustrate', b'thread', 'curator', 'exhort